# %%
import pandas as pd
import os
import datetime

# %%
# Get the list of all files and directories
path ='C:/Users/91766/Desktop/learn/bsedata'
bse_list = os.listdir(path)
bse_list[0]
# Out:
# 'EQ010108.CSV'

# %%
df=pd.read_csv(r'C:/Users/91766/Desktop/learn/bsedata/'+bse_list[0])
df
# Out:
#       SC_CODE       SC_NAME SC_GROUP SC_TYPE     OPEN     HIGH      LOW  \
# 0      526921  21ST CEN.MGM       B        Q   109.70   113.50   106.00
# 1      532628  3I INFOTECH        B1       Q   148.00   149.85   147.00
# 2      523395  3M INDIA LTD       B1       Q  2325.00  2325.00  2280.00
# 3      990001  6.75% US-64        F        B    97.20    97.50    97.11
# 4      530499  A.K.CAPITAL        B        Q   370.00   419.95   365.00
# ...       ...           ...      ...     ...      ...      ...      ...
# 2901   512587  ZODIAC JRD         B        Q    48.15    48.40    43.20
# 2902   530283  ZUARI FOREX        Z        Q    13.20    13.20    13.20
# 2903   500780  ZUARI INDUS.       B1       Q   442.95   455.00   430.00
# 2904   530091  ZYDEN GENTEC       T        Q    34.30    35.75    34.25
# 2905   532883  ZYLOG SYSTEM       B1       Q   420.00   443.70   418.05
#
#         CLOSE     LAST  PREVCLOSE  NO_TRADES  NO_OF_SHRS  NET_TURNOV TDCLOINDI
# ...
