# %%
import pandas as pd
from NSEDownload import stocks
from os import path

# %%
company_csv = pd.read_csv('NSECOMPANYLIST.csv')
size = company_csv.size
not_downloaded = []
for x in range(0,size):
    symbol = company_csv.SYMBOL[x]
    if(path.exists(r'C:\Users\Divyanshu\Desktop\Project Stock Analysis\NSEDATA\ ' + symbol + ".csv")):
        print("" , end="")
    else:
            try:
                df = stocks.get_data(stockSymbol=symbol, start_date = '01-01-2005', end_date = '22-06-2021')
                df.to_csv(r'C:\Users\Divyanshu\Desktop\Project Stock Analysis\NSEDATA\ ' + symbol + ".csv")
            except:
                print(symbol)
# Out:
# AAKASH
# AARON
# AARTISURF
# AARVI
# ACCURACY
# ACRYSIL
# ADL
# AHLADA
# AJOONI
# AKG
# ALOKINDS
# AMBICAAGAR
# ANDHRAPAP
# ANGELBRKG
# ANMOL
# ANURAS
# APOLLOPIPE
# ARIHANTCAP
# ARTEMISMED
# ARVEE
# ASALCBR
# ATGL
# AWHCL
# BAFNAPH
# BANKA
# BARBEQUE
# BCLIND
# BECTORFOOD
# BESTAGRO
# BIRLATYRE
# BOROLTD
# BORORENEW
# BSHSL
# BURGERKING
# CAMS
# CCCL
# CHEMBOND
# CHEMCON
# CLSEL
# COFORGE
# COX&KINGS
# Unsuccessful attempt. Trying again.
# Error : Empty dataframe. Please try Again.
# ...
# CRAFTSMAN
# CSBBANK
# DALALSTCOM
# DANGEE
# DEEPENR
# DEEPINDS
# DHANI
# DPABHUSHAN
# DPWIRES
# DRCSYSTEMS
# EASEMYTRIP
# EBIXFOREX
# EPL
# EQUITASBNK
# FAIRCHEMOR
# GEEKAYWIRE
# GENCON
# GET&D
# Unsuccessful attempt. Trying again.
# Error : Empty dataframe. Please try Again.
# ...
# GLAND
# GLOBAL
# GLOBE
# GODHA
# GOODYEAR
# GUJRAFFIA
# Unsuccessful attempt. Trying again.
# Error : Empty dataframe. Please try Again.
# ...
# HAPPSTMNDS
# HEMIPROP
# HERANBA
# HLEGLAS
# HLVLTD
# HOMEFIRST
# HUHTAMAKI
# ICEMAKE
# ...
