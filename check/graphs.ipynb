# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf

# %%
df = pd.read_csv("RELIANCE.csv" ,parse_dates=["Date"])
df
# Out:
#            Date    Symbol Series  Prev Close  Open Price  High Price  \
# 0    2021-06-22  RELIANCE     EQ     2237.25      2254.0     2261.00
# 1    2021-06-21  RELIANCE     EQ     2225.65      2203.5     2247.50
# 2    2021-06-18  RELIANCE     EQ     2215.65      2225.5     2235.00
# 3    2021-06-17  RELIANCE     EQ     2211.60      2200.0     2235.00
# 4    2021-06-16  RELIANCE     EQ     2250.00      2244.9     2247.05
# ...         ...       ...    ...         ...         ...         ...
# 4213 2005-07-01  RELIANCE     EQ      642.55       643.0      645.00
# 4214 2005-06-30  RELIANCE     EQ      641.85       648.0      653.15
# 4215 2005-06-29  RELIANCE     EQ      629.55       634.0      647.00
# 4216 2005-06-28  RELIANCE     EQ      648.65       670.0      670.00
# 4217 2005-06-27  RELIANCE     EQ      654.65       648.0      675.00
#
#       Low Price  Last Price  Close Price  Average Price  \
# 0       2219.35     2225.00      2225.75        2245.45
# ...

# %%
df.set_index("Date",inplace=True)
df
# Out:
#               Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2021-06-22  RELIANCE     EQ     2237.25      2254.0     2261.00    2219.35
# 2021-06-21  RELIANCE     EQ     2225.65      2203.5     2247.50    2200.15
# 2021-06-18  RELIANCE     EQ     2215.65      2225.5     2235.00    2184.35
# 2021-06-17  RELIANCE     EQ     2211.60      2200.0     2235.00    2179.90
# 2021-06-16  RELIANCE     EQ     2250.00      2244.9     2247.05    2205.85
# ...              ...    ...         ...         ...         ...        ...
# 2005-07-01  RELIANCE     EQ      642.55       643.0      645.00     637.55
# 2005-06-30  RELIANCE     EQ      641.85       648.0      653.15     636.65
# 2005-06-29  RELIANCE     EQ      629.55       634.0      647.00     632.70
# 2005-06-28  RELIANCE     EQ      648.65       670.0      670.00     627.15
# 2005-06-27  RELIANCE     EQ      654.65       648.0      675.00     645.25
#
# ...

# %%
df.rename(columns={
    "Open Price":"Open",
    "Close Price":"Close",
    "Low Price":"Low",
    "High Price":"High",
    "Total Traded Quantity":"Volume"
},inplace=True)
df
# Out:
#               Symbol Series  Prev Close    Open     High      Low  Last Price  \
# Date
# 2021-06-22  RELIANCE     EQ     2237.25  2254.0  2261.00  2219.35     2225.00
# 2021-06-21  RELIANCE     EQ     2225.65  2203.5  2247.50  2200.15     2238.95
# 2021-06-18  RELIANCE     EQ     2215.65  2225.5  2235.00  2184.35     2224.15
# 2021-06-17  RELIANCE     EQ     2211.60  2200.0  2235.00  2179.90     2214.15
# 2021-06-16  RELIANCE     EQ     2250.00  2244.9  2247.05  2205.85     2209.55
# ...              ...    ...         ...     ...      ...      ...         ...
# 2005-07-01  RELIANCE     EQ      642.55   643.0   645.00   637.55      638.70
# 2005-06-30  RELIANCE     EQ      641.85   648.0   653.15   636.65      642.40
# 2005-06-29  RELIANCE     EQ      629.55   634.0   647.00   632.70      643.00
# 2005-06-28  RELIANCE     EQ      648.65   670.0   670.00   627.15      628.60
# 2005-06-27  RELIANCE     EQ      654.65   648.0   675.00   645.25      646.65
#
# ...

# %%
s = mpf.make_mpf_style(base_mpf_style='yahoo',y_on_right=False,gridstyle=':')
mpf.plot(df.head(100),mav=(9,26),type='candlestick', style=s, volume=True )
