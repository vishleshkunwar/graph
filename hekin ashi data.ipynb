# %%
import pandas as pd

# %%
df =pd.read_csv('C:/Users/91766/Desktop/learn/nsedata/ACC.csv')
df=df[['Date', 'Symbol','Open Price', 'High Price',
       'Low Price','Close Price']]
df=df.head(30)
df=df.loc[::-1]
df=df.iloc[0:30,0:6]
df['ha-open'] = 0
df['ha-high'] = 0
df['ha-low'] = 0
df['ha-close'] = 0
df.reset_index(inplace=True)
df['ha-open'] = df['ha-open'].astype(float)
df['ha-high'] = df['ha-high'].astype(float)
df['ha-low'] = df['ha-low'].astype(float)
df['ha-close'] = df['ha-close'].astype(float)

# %%
for i in range(0,30):
    if(i==0):
        df['ha-open'][i] = df['Open Price'][i]
        df['ha-close'][i] = df['Close Price'][i]
        df['ha-low'][i]  = df['Low Price'][i]
        df['ha-high'][i] = df['High Price'][i]
    else:
        df['ha-open'][i] = round((df['ha-open'][i-1] + df['ha-close'][i-1])/2,2)
        df['ha-close'][i] = round((df['Close Price'][i] + df['Open Price'][i] + df['High Price'][i] + df['Low Price'][i])/4,2)
        df['ha-high'][i]  = round(max(df['Close Price'][i] , df['Open Price'][i] , df['High Price'][i]),2)
        df['ha-low'][i] = round(min(df['Close Price'][i] , df['Open Price'][i] , df['Low Price'][i]),2)
df
# Out:
# <ipython-input-4-c972f99e06ed>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ha-open'][i] = df['Open Price'][i]
# <ipython-input-4-c972f99e06ed>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ha-close'][i] = df['Close Price'][i]
# <ipython-input-4-c972f99e06ed>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ha-low'][i]  = df['Low Price'][i]
# <ipython-input-4-c972f99e06ed>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ha-high'][i] = df['High Price'][i]
# <ipython-input-4-c972f99e06ed>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ha-open'][i] = round((df['ha-open'][i-1] + df['ha-close'][i-1])/2,2)
# <ipython-input-4-c972f99e06ed>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ha-close'][i] = round((df['Close Price'][i] + df['Open Price'][i] + df['High Price'][i] + df['Low Price'][i])/4,2)
# <ipython-input-4-c972f99e06ed>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ha-high'][i]  = round(max(df['Close Price'][i] , df['Open Price'][i] , df['High Price'][i]),2)
# <ipython-input-4-c972f99e06ed>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ha-low'][i] = round(min(df['Close Price'][i] , df['Open Price'][i] , df['Low Price'][i]),2)
#     index         Date Symbol  Open Price  High Price  Low Price  Close Price  \
# 0      29  10-May-2021    ACC     1918.50     1921.00    1880.25      1885.70
# 1      28  11-May-2021    ACC     1870.00     1920.00    1860.25      1909.95
# 2      27  12-May-2021    ACC     1903.90     1909.95    1877.00      1882.70
# 3      26  14-May-2021    ACC     1893.75     1898.90    1854.00      1876.80
# 4      25  17-May-2021    ACC     1877.35     1907.75    1867.40      1903.60
# 5      24  18-May-2021    ACC     1916.00     1951.85    1906.05      1939.95
# 6      23  19-May-2021    ACC     1939.45     1982.00    1917.00      1927.25
# 7      22  20-May-2021    ACC     1940.00     1963.50    1921.00      1958.15
# 8      21  21-May-2021    ACC     1970.05     1987.95    1959.30      1965.25
# 9      20  24-May-2021    ACC     1968.00     1997.90    1953.00      1984.45
# 10     19  25-May-2021    ACC     1995.00     1995.40    1953.40      1961.20
