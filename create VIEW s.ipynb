# %%
import pandas as pd
import mysql.connector
import sqlalchemy
import pymysql

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:vishal@127.0.0.1:3306/company')

# %%
df = pd.read_sql("select Date,Symbol,Prev_close,open,high,low,last_price,close,volume FROM company.reliance where (`Date` between '2021-05-22' and '2021-06-22') order by `Date` asc", engine)

# %%
df
# Out:
#           Date    Symbol  Prev_close    open     high      low  last_price  \
# 0   2021-05-24  RELIANCE     2002.55  2008.0  2009.80  1982.00     1985.05
# 1   2021-05-25  RELIANCE     1985.65  1996.4  1997.00  1960.00     1964.00
# 2   2021-05-26  RELIANCE     1963.15  1975.0  1979.50  1965.30     1967.00
# 3   2021-05-27  RELIANCE     1970.05  1970.3  1993.00  1962.25     1990.00
# 4   2021-05-28  RELIANCE     1976.10  1990.0  2105.00  1990.00     2094.45
# 5   2021-05-31  RELIANCE     2094.80  2102.0  2191.70  2085.05     2153.50
# 6   2021-06-01  RELIANCE     2160.30  2166.0  2202.00  2146.50     2164.30
# 7   2021-06-02  RELIANCE     2168.90  2157.0  2209.50  2157.00     2207.00
# 8   2021-06-03  RELIANCE     2201.25  2221.0  2250.00  2196.10     2208.00
# 9   2021-06-04  RELIANCE     2209.65  2214.8  2216.45  2184.25     2186.90
# 10  2021-06-07  RELIANCE     2190.50  2202.0  2242.00  2185.00     2225.05
# ...

# %%
list_ = df['symbol'].tolist()
list_
# Out:
# ['20MICRONS',
#  '21STCENMGM',
#  '3IINFOTECH',
#  '3MINDIA',
#  '3PLAND',
#  'PDUMJEIND',
#  'PDUMJEAGRO',
#  '5PAISA',
#  '63MOONS',
#  'FINANTECH',
#  'A2ZINFRA',
#  'A2ZMES',
#  'AARTIDRUGS',
#  'AARTIIND',
#  'AARVEEDEN',
#  'AAVAS',
#  'ABAN',
#  'ABANLOYD',
#  'ABANLLOYD',
#  'ABB',
#  'ABBOTINDIA',
#  'ABCAPITAL',
#  'ABFRL',
#  'PFRL',
#  'ABMINTLTD',
#  'ACC',
#  'ACCELYA',
#  'KALECONSUL',
#  'ACE',
#  'ADANIENT',
#  'ADANIEXPO',
#  'ADANIGREEN',
#  'ADANIPORTS',
#  'MUNDRAPORT',
#  'ADANIPOWER',
#  'ADANITRANS',
#  'ADFFOODS',
#  'ADORWELD',
#  'ADROITINFO',
#  'SPHEREGSL',
#  'COLORCHIPS',
#  'ARHAMFISCL',
#  'ADSL',
#  'ADVANIHOTR',
#  'ADVENZYMES',
#  'AEGISCHEM',
#  'AFFLE',
#  'AGARIND',
#  'AGCNET',
#  'AVAYAGCL',
#  'AGRITECH',
#  'AGROPHOS',
#  'AHLEAST',
#  'AHLUCONT',
#  'AHLWEST',
#  'AIAENG',
#  'AIRAN',
#  'AJANTPHARM',
#  'AJMERA',
#  'SHREE',
#  'AKASH',
#  'AKSHARCHEM',
#  'AKSHOPTFBR',
#  'AKZOINDIA',
#  'ICI',
#  'ALANKIT',
#  'ALBERTDAVD',
# ...

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="vishal",
  database="company"
)

mycursor = mydb.cursor()
for i in list_:
    mycursor.execute("CREATE VIEW `"+i+"` as select * from stockdata WHERE symbol='"+i+"'")
